# %%
from sensor.utils.main_utils import read_yaml_file

# %%
file_path="C:\FAU_DS\DS Project\Data-Driven-Air-Pressure-System-APS-sensor-fault-detection\config\schema.yaml"

# %%
schema_config=read_yaml_file(file_path=file_path)

# %%
schema_config['columns']
# Out:
# [{'class': 'category'},
#  {'aa_000': 'int'},
#  {'ac_000': 'int'},
#  {'ad_000': 'int'},
#  {'ae_000': 'int'},
#  {'af_000': 'int'},
#  {'ag_000': 'int'},
#  {'ag_001': 'int'},
#  {'ag_002': 'int'},
#  {'ag_003': 'int'},
#  {'ag_004': 'int'},
#  {'ag_005': 'int'},
#  {'ag_006': 'int'},
#  {'ag_007': 'int'},
#  {'ag_008': 'int'},
#  {'ag_009': 'int'},
#  {'ah_000': 'int'},
#  {'ai_000': 'int'},
#  {'aj_000': 'int'},
#  {'ak_000': 'int'},
#  {'al_000': 'int'},
#  {'am_0': 'int'},
#  {'an_000': 'int'},
#  {'ao_000': 'int'},
#  {'ap_000': 'int'},
#  {'aq_000': 'int'},
#  {'ar_000': 'int'},
#  {'as_000': 'int'},
#  {'at_000': 'int'},
#  {'au_000': 'int'},
#  {'av_000': 'int'},
#  {'ax_000': 'int'},
#  {'ay_000': 'int'},
#  {'ay_001': 'int'},
#  {'ay_002': 'int'},
#  {'ay_003': 'int'},
#  {'ay_004': 'int'},
#  {'ay_005': 'int'},
#  {'ay_006': 'int'},
#  {'ay_007': 'int'},
#  {'ay_008': 'int'},
#  {'ay_009': 'int'},
#  {'az_000': 'int'},
#  {'az_001': 'int'},
#  {'az_002': 'int'},
# ...

# %%
from scipy.stats import ks_2samp

# %%
import numpy as np

# %%
d1=np.arange(100,200)
d2=np.arange(10)

# %%
test=ks_2samp(d1,d2)

# %%
d3=np.arange(11)
d4=np.arange(10)

# %%
ks_2samp(d3,d4)
# Out:
# KstestResult(statistic=0.09090909090909091, pvalue=1.0, statistic_location=9, statistic_sign=-1)

# %%
test.pvalue
# Out:
# 4.2646072253826637e-14

# %%
round(test.pvalue,6)
# Out:
# 0.0

# %%
train_file_path="C:\FAU_DS\DS Project\Data-Driven-Air-Pressure-System-APS-sensor-fault-detection\artifact\12_18_2025_05_04_36\data_ingestion\ingested\train.csv"

# %%
test_file_path="C:\FAU_DS\DS Project\Data-Driven-Air-Pressure-System-APS-sensor-fault-detection\artifact\12_18_2025_05_04_36\data_ingestion\ingested\test.csv"

# %%
import pandas as pd

train_df = pd.read_csv(
    r"C:\FAU_DS\DS Project\Data-Driven-Air-Pressure-System-APS-sensor-fault-detection\artifact\12_18_2025_05_04_36\data_ingestion\ingested\train.csv"
)
test_df = pd.read_csv(
    r"C:\FAU_DS\DS Project\Data-Driven-Air-Pressure-System-APS-sensor-fault-detection\artifact\12_18_2025_05_04_36\data_ingestion\ingested\test.csv"
)

# %%
train_df.columns
# Out:
# Index(['class', 'aa_000', 'ab_000', 'ac_000', 'ad_000', 'ae_000', 'af_000',
#        'ag_000', 'ag_001', 'ag_002',
#        ...
#        'ee_002', 'ee_003', 'ee_004', 'ee_005', 'ee_006', 'ee_007', 'ee_008',
#        'ee_009', 'ef_000', 'eg_000'],
#       dtype='object', length=171)

# %%
test_df.columns
# Out:
# Index(['class', 'aa_000', 'ab_000', 'ac_000', 'ad_000', 'ae_000', 'af_000',
#        'ag_000', 'ag_001', 'ag_002',
#        ...
#        'ee_002', 'ee_003', 'ee_004', 'ee_005', 'ee_006', 'ee_007', 'ee_008',
#        'ee_009', 'ef_000', 'eg_000'],
#       dtype='object', length=171)

# %%
d1=train_df['aa_000']
d2=test_df['aa_000']

# %%
ks_2samp(d1,d2)
# Out:
# KstestResult(statistic=0.009972907333727576, pvalue=0.6086210720143939, statistic_location=90290, statistic_sign=1)

# %%
colums=list(train_df.columns)

# %%
## Categorical columns
d3=train_df['class']
d4=test_df['class']
ks_2samp(d3,d4)
# Out:
# KstestResult(statistic=0.0010381211042659322, pvalue=1.0, statistic_location='neg', statistic_sign=-1)

# %%
report={}
def get_drift_report(base_df,current_df, threshold=0.60):
    report={}
    for column in train_df.columns:
        d1=train_df[column]
        d2=test_df[column]
        is_same_dist=ks_2samp(d1,d2)
        if is_same_dist.pvalue>=threshold:
            is_found=False
        else:
            is_found=True
            report.update({column:{
                "pvalue":float(is_same_dist.pvalue),
                "drift_status":is_found
            }})
    return report

# %%
report={}
def get_drift_report(base_df,current_df, threshold=0.60):
    report={}
    for column in train_df.columns:
        d1=train_df[column]
        d2=test_df[column]
        is_same_dist=ks_2samp(d1,d2)
        if is_same_dist.pvalue>=threshold:
            is_found=False
        else:
            is_found=True
            report.update({column:{
                "pvalue":float(is_same_dist.pvalue),
                "drift_status":is_found
            }})
    return report
